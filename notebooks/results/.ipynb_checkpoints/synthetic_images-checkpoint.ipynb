# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from growth.sweep.sweep import Sweep
# %matplotlib inline

# %%
def take_along_axis(arr, ind, axis):
    """
    ... here means a "pack" of dimensions, possibly empty

    arr: array_like of shape (A..., M, B...)
        source array
    ind: array_like of shape (A..., K..., B...)
        indices to take along each 1d slice of `arr`
    axis: int
        index of the axis with dimension M

    out: array_like of shape (A..., K..., B...)
        out[a..., k..., b...] = arr[a..., inds[a..., k..., b...], b...]
    """
    if axis < 0:
        if axis >= -arr.ndim:
           axis += arr.ndim
        else:
            raise IndexError('axis out of range')
    ind_shape = (1,) * ind.ndim
    ins_ndim = ind.ndim - (arr.ndim - 1)   #inserted dimensions

    dest_dims = list(range(axis)) + [None] + list(range(axis+ins_ndim, ind.ndim))

    # could also call np.ix_ here with some dummy arguments, then throw those results away
    inds = []
    for dim, n in zip(dest_dims, arr.shape):
        if dim is None:
            inds.append(ind)
        else:
            ind_shape_dim = ind_shape[:dim] + (-1,) + ind_shape[dim+1:]
            inds.append(np.arange(n).reshape(ind_shape_dim))

    return arr[tuple(inds)]

# %%
ls ../../../data/synthetic/sweeps/Sweep_181201_191516/
# Out:
# batches/     data.hdf     log/         scripts/
# benchmark/   job.pkl      notes.txt    simulations/

# %%
sweep_path = '../../../data/synthetic/sweeps/Sweep_181201_191516/'
sweep = Sweep.load(sweep_path)
sweep
# Out:
# 1 x 16 sweep, 4 recombination generations

# %%
from clones.validation.training import Training
from clones.annotation.spatial.correlation import CharacteristicLength
from clones.annotation.spatial.timeseries import smooth, savgol, get_running_mean
from clones.annotation.spatial.sampling import CommunitySampler

# %%
sampler = CommunitySampler(graph, 'clonal_marker')

# %%
sampler.plot_autocorrelation()

# %%
correlations = graph.get_correlations('clonal_marker')

# %%
fig, ax = plt.subplots(figsize=(2, 1.25))
correlations.visualize(ax=ax)
ax.set_xlim(0, 1.5)
ax.set_ylim(0, .8)
# Out:
# /Users/Sebi/.virtualenvs/clones/lib/python3.6/site-packages/matplotlib/axes/_base.py:3124: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0.0
#   'left=%s, right=%s') % (left, right))
# (0, 0.8)

# %%
char = CharacteristicLength(correlations)
char.plot()

# %%
detector = InfoMap(graph.edge_list)

# %%
detector.aggregator.max_depth
# Out:
# 5

# %%
detector.infomap.maxTreeDepth()
# Out:
# 5

# %%
simulation = sweep[0]

# %%
data = simulation.measure(.5)
graph = Training.build_graph(data, logratio=True)

# %%
from clones.annotation.spatial.infomap import InfoMap
from matplotlib.colors import ListedColormap, Normalize

# %%
imap = InfoMap(graph.edge_list)

# %%
num_levels = imap.infomap.maxTreeDepth()

labels = {}
for depth in range(num_levels):
    labels[depth] = imap(graph.nodes, level=depth)

num_modules = np.unique(labels[0]).size
cmap = ListedColormap(np.random.random((num_modules, 3)))

# %%
values = np.log(graph.data.clonal_marker)
mu, sigma = values.mean(), values.std()
norm = Normalize(vmin=mu-sigma, vmax=mu+sigma)

fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(*graph.node_positions_arr.T, c=graph.data.clonal_marker, s=10, cmap=plt.cm.viridis)

fig, axes = plt.subplots(ncols=num_levels, figsize=(5*num_levels, 5))

for j, i in enumerate(range(num_levels)[::-1]):
    label_to_level = graph.data.groupby(labels[i])['clonal_marker'].agg(lambda x: np.log(x).mean()).to_dict()
    assign_levels = np.vectorize(label_to_level.get)
    colors = norm(assign_levels(labels[i]))
    
    axes[j].scatter(*graph.node_positions_arr.T, c=colors, s=10, cmap=plt.cm.copper, vmin=0, vmax=1)
    axes[j].axis('off')

# %%
CharacteristicLength(self).characteristic_length

# %%
image = simulation.generate_microscopy(ambiguity=0.3, rho=0.5, bleedthrough=0.5)

# %%
_ = image.render()

# %%
clonal_marker = image.measure(1)
control = image.measure(2)

# %%
from clones.validation import SimulationBenchmark

# %%
data = simulation.measure(.5)

# %%
training_kw = dict(max_num_components=3, sampler_kwargs=dict(depth=0.5))
benchmark = SimulationBenchmark(data, attribute='clonal_marker', training_kw=training_kw)

# %%
classifier = benchmark.classifier
classifier()

# %%
benchmark.MAE
# Out:
# 0.10515829207399557

# %%
benchmark.MAE_comm
# Out:
# 0.15280013413198593

# %%
benchmark.MAE_levels
# Out:
# 0.23463777426362778

# %%
benchmark.MAE_spatial
# Out:
# 0.10392163543775908

# %%
from clones.validation import BatchBenchmark
