# %%
import sys, os
from glob import glob
p = '../'
if p not in sys.path:
    sys.path.insert(0, p)

# %%
from clones.data.experiments import Experiment
from clones.bleedthrough.correction import LayerCorrection

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Load layer data

# %%
experiment_path = '../data/clones/yanE833'

# load experiment
experiment = Experiment(experiment_path)

# load stack
stack_id = 0
stack = experiment.load_stack(stack_id, full=True)

# load layer
layer_id = 0
layer = stack[layer_id]

# %% [markdown]
# # Perform bleedthrough correction

# %%
# perform correction
correction = LayerCorrection(layer, niters=20)

# save correction
#correction.save()

# %% [markdown]
# # Visualize bleedthrough correction

# %%
# plot fit to background pixel trend
correction.show_fit()

# plot measurements before and after correction
correction.show_correction()
